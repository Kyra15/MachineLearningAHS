# %%
# !pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.5/31.5 MB 39.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.1/795.1 kB 65.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 73.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 55.2 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 82.2 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 91.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 68.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/22 [numpy]  WARNING: The scripts f2py and numpy-config are installed in '/home/jupyter-251201/.local/bin' which is not on PATH.
# ...

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 71.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 789.9/789.9 kB 65.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [nltk]  WARNING: The script nltk is installed in '/home/jupyter-251201/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nltk]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 81.8 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import nltk
import string

nltk.download('vader_lexicon')

text = '''
Hello Math Competition Team!

We have now completed the first three weeks of testing, and it is time to put out the first official rankings for each division.  While these rankings will change substantially during the next few months, they are a good first indication of how everyone is doing.  We will also take a first look as to how the top six average scores per week compare to previous years.  Why top six?  Because teams function best when there are both a full four members doing well, and two alternates who could potentially take their place.

For these calculations, we dropped the lowest Individual+Ciphering and Speed from among the three tests for each student.  Composites are calculated with Individual+Ciphering weighted twice and Speed weighted once, except for Statistics which does not count Speed.  

Here, we present only students whose composite is at least 50.00 or higher;  50.00 is average for each test.  If you do not appear on a list and wish to know your ranking, you can email me for that information.

GEOMETRY	Drop 1
Arnav Bhatia	90.45
Jonny Jiang	67.20
Samay Arora	66.38
James Zhao	65.64
Platon Nesmeyanov	62.44
Ivanshi Gadani	61.48
Angela Liang	59.99
Rex Lee	56.90
Carson Liu	56.60
Jesse Xiao	55.46
Andrea Win	54.72
Siyona Narang	53.89
Lucas Wu	53.36
Aariv Chawla	52.88
Aiden Essmyer	51.84
Sayem Khursheed	51.67
Riyon Robin	51.05
Jithya Rubesh	50.91
Risheek De	50.75

image.png

Comment:  An overall excellent early showing for Geometry, with the first three weeks matching or exceeding the last four years.

ALGEBRA 2	Drop 1
Arnav Bhatia	83.37
Angela Liang	63.34
Ivanshi Gadani	61.47
Jonny Jiang	61.16
James Zhao	59.41
Jesse Xiao	57.30
Platon Nesmeyanov	57.16
Samay Arora	56.31
Rex Lee	56.10
Aiden Essmyer	55.70
Aariv Chawla	53.99
Andrea Win	52.97
Noah Palacios	50.93
Siyona Narang	50.93
Risheek De	50.80

image.png

Comment:  A moderate Week 1, followed by a strong Week 2 and a low Week 3 indicated some inconsistency in either knowledge base or preparation.  Remember that these are designed to be practice, and if you did not perform well on a specific topic, you should want to review that topic so it doesn't happen again.  TAs and instructors should also provide some review.

PRECALCULUS	Drop 1
Arnav Bhatia	72.59
Hanfei He	66.87
Jesse Deng	64.57
Neel Ganeriwala	62.56
Dhruv Ralhan	61.93
Ariv Barua	60.90
Alexander Allain	59.02
Asher Bernstein	57.31
Henry Pratt	55.95
Christian Azaret	53.01
Bhavin Pinjarla	52.93
Christine Yu	52.91
Dhava Rajamanikandan	50.51
Rachel Lagrotte	50.09

image.png

Comment:  Unequivocally and consistently the worst post-pandemic performance by a Precalculus group, even after adding in Arnav.  This is a group more interested in goofing around than studying and which seems to pride itself on not caring, when the reality is the only emotion you should be feeling is embarrassment.   It's going to take work to get yourselves out of the hole of ignorance you are in, and the time to fix it is now.

STATISTICS	Drop 1
Lauren Lee	73.15
Daniel Zhao	68.83
Kabir Gandhi	63.75
Jacob Khohayting	62.26
Anika Mishra	61.33
Lexi Dougherty	59.57
Ellie Kong	59.15
Sanvi Pandya	57.37
Maximus Callis	55.60
Bennett Ortiz	54.65
Julia Diez	54.07
Kyra Movva	52.91
Anthony Rodriguez	52.68
Lance Stus	52.24
Jonathan Schwartz	51.69
Krishang Thakkar	51.25

image.png

Comment:  Scores dropped off markedly after a reasonably good Week 1 to levels comparable with the worst years' performances.  It remains to be seen where this group ends up, but it isn't looking great and it's up to you to fix it.

CALCULUS	Drop 1
Aaron Alter	73.10
Darsh Patel	71.59
Jayden Lang	70.97
Katie Lee	67.26
Ishika Gadani	65.88
Jonathan Wu	63.85
Liz Xiao	62.55
Jason Tang	62.43
Kabir Gandhi	62.10
Andrey Vasilyev	58.50
Jacob Khohayting	56.62
Lance Stus	55.28
Gaby Kucher	54.80
Daniel Cai	54.12
Bennett Ortiz	54.07
Julie Ye	53.32
Daniel Zhao	52.95
Anthony Rodriguez	52.52
Leo Liu	51.61

image.png

Comment:  This is also extremely close to the worst performance by a Calculus group since 2021.  Here, the numbers are getting reduced by positions 3-6 in the top six.  More students need to step up and prepare better, because as with Precalculus this is not an easy hole to get out of.
'''
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jupyter-251201/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
analyzer = SentimentIntensityAnalyzer()
lexicon = analyzer.lexicon

negative_words = [word for word, score in lexicon.items() if score < 0]

# https://stackoverflow.com/questions/34293875/how-to-remove-punctuation-marks-from-a-string-in-python-3-x-using-translate
text = text.lower().translate(str.maketrans("", "", string.punctuation))
words = text.split()

word_counts = Counter(words)

negative_counts = {word: count for word, count in word_counts.items() if word in negative_words}

print("Negative word counts:", negative_counts)
print("Total negative words:", sum(negative_counts.values()))
# Out:
# Negative word counts: {'lowest': 1, 'drop': 5, 'low': 1, 'worst': 3, 'embarrassment': 1, 'ignorance': 1}
# Total negative words: 12
